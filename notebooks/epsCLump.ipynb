# %%
import matplotlib.pyplot as plt
import pandas as pd 
from IPython.display import Image, display

def my_display(prefix_figures,view,suffix):
    #display(Image(filename=prefix_figures+'_'+view+'_5Drift_nRows3_eps0.28164_max_alw_slope_0.1.JPG',width=700))
    display(Image(filename=prefix_figures+'_'+view+suffix,width=700))

# %% [markdown]
# # Largest epsilon up to max error given by max percentage drift slope

# %%
## Barua-experiments take a lot of time. I should run them over night

# %%
#print('REDO EXPERIMENT')
#pd.read_csv('../epsCLump_approximateCLump/otherBNG/barua_Ig_alpha_P.csv', sep=',')

# %% [markdown]
# ## BioNetGen_CCP-VERY GOOD

# %% [markdown]
# ### D13PG

# %%
print('THIS IS IN GENERAL VERY GOOD')
print('maxPert=0,nRows=27 == nRows=23')
print('maxPert=5,nRows=73 PERFECT')
print('         ,nRows=26 GOOD')
pd.read_csv('../epsCLump_approximateCLump/otherBNG/BioNetGen_CCP_D13PG.csv', sep=',')
# Out:
# THIS IS IN GENERAL VERY GOOD
# maxPert=0,nRows=27 == nRows=23
# maxPert=5,nRows=73 PERFECT
#          ,nRows=26 GOOD
#                  modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    BioNetGen_CCP_D13PG_0                0    87           30     30
# 1    BioNetGen_CCP_D13PG_0                0    87           30     27
# 2    BioNetGen_CCP_D13PG_0                0    87           30     23
# 3    BioNetGen_CCP_D13PG_0                0    87           30      9
# 4    BioNetGen_CCP_D13PG_0                0    87           30      9
# 5    BioNetGen_CCP_D13PG_5                5    87           87     81
# 6    BioNetGen_CCP_D13PG_5                5    87           87     76
# 7    BioNetGen_CCP_D13PG_5                5    87           87     66
# 8    BioNetGen_CCP_D13PG_5                5    87           87     10
# 9    BioNetGen_CCP_D13PG_5                5    87           87     10
# 10  BioNetGen_CCP_D13PG_10               10    87           87     83
# ...

# %%
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_D13PG_0Drift_nRows23_eps0.34426_max_alw_slope_0.3.jpg',width=700))

# %%
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_D13PG_5Drift_nRows73_eps0.14324_max_alw_slope_0.2.jpg',width=700))

# %%
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_D13PG_5Drift_nRows26_eps0.25_max_alw_slope_0.3.jpg',width=700))

# %% [markdown]
# ### P6GL good (some bad cases)

# %%
print('This looks BAD and GOOD')
print('VERY BAD: maxPert=0,eps=0.29')
print('GOOD: maxPert=5,eps=0.27')
pd.read_csv('../epsCLump_approximateCLump/otherBNG/BioNetGen_CCP_P6GL.csv', sep=',')
# Out:
# This looks BAD and GOOD
# VERY BAD: maxPert=0,eps=0.29
# GOOD: maxPert=5,eps=0.27
#                 modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    BioNetGen_CCP_P6GL_0                0    87            4      4
# 1    BioNetGen_CCP_P6GL_0                0    87            4      1
# 2    BioNetGen_CCP_P6GL_0                0    87            4      1
# 3    BioNetGen_CCP_P6GL_0                0    87            4      1
# 4    BioNetGen_CCP_P6GL_0                0    87            4      1
# 5    BioNetGen_CCP_P6GL_5                5    87           86      4
# 6    BioNetGen_CCP_P6GL_5                5    87           86      1
# 7    BioNetGen_CCP_P6GL_5                5    87           86      1
# 8    BioNetGen_CCP_P6GL_5                5    87           86      1
# 9    BioNetGen_CCP_P6GL_5                5    87           86      1
# 10  BioNetGen_CCP_P6GL_10               10    87            7      4
# ...

# %%
print('very bad')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_P6GL_0Drift_nRows1_eps0.29004_max_alw_slope_0.2.jpg',width=700))
# Out:
# very bad

# %%
print('very good')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_P6GL_5Drift_nRows4_eps0.27847_max_alw_slope_0.1.jpg',width=700))
# Out:
# very good

# %% [markdown]
# ### FUM

# %%
print('This view is not interesting')
#pd.read_csv('../epsCLump_approximateCLump/otherBNG/BioNetGen_CCP_FUM.csv', sep=',')
# Out:
# This view is not interesting

# %%
#pd.read_csv('../epsCLump_approximateCLump/otherBNG/BioNetGen_CCP_D13PG.csv', sep=',')

# %% [markdown]
# ### P6GC

# %%
print('BAD: maxPert=0,nRows=1')
print('GOOD: maxPert=5,nRows=5')
print('GOOD-: maxPert=10,nRows=5')
print('GOOD--: maxPert=15,nRows=5')
pd.read_csv('../epsCLump_approximateCLump/otherBNG/BioNetGen_CCP_P6GC.csv', sep=',')
# Out:
# BAD: maxPert=0,nRows=1
# GOOD: maxPert=5,nRows=5
# GOOD-: maxPert=10,nRows=5
# GOOD--: maxPert=15,nRows=5
#                 modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    BioNetGen_CCP_P6GC_0                0    87            5      5
# 1    BioNetGen_CCP_P6GC_0                0    87            5      1
# 2    BioNetGen_CCP_P6GC_0                0    87            5      1
# 3    BioNetGen_CCP_P6GC_0                0    87            5      1
# 4    BioNetGen_CCP_P6GC_0                0    87            5      1
# 5    BioNetGen_CCP_P6GC_5                5    87           86      5
# 6    BioNetGen_CCP_P6GC_5                5    87           86      1
# 7    BioNetGen_CCP_P6GC_5                5    87           86      1
# 8    BioNetGen_CCP_P6GC_5                5    87           86      1
# 9    BioNetGen_CCP_P6GC_5                5    87           86      1
# 10  BioNetGen_CCP_P6GC_10               10    87           86      5
# ...

# %%
print('very bad')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_P6GC_0Drift_nRows1_eps0.45_max_alw_slope_0.2.jpg',width=700))
# Out:
# very bad

# %%
print('good')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_P6GC_5Drift_nRows5_eps0.29181_max_alw_slope_0.1.jpg',width=700))
# Out:
# good

# %%
print('good-')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_P6GC_10Drift_nRows5_eps0.29184_max_alw_slope_0.1.jpg',width=700))
# Out:
# good-

# %%
print('good---')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_P6GC_15Drift_nRows5_eps0.27341_max_alw_slope_0.1.jpg',width=700))
# Out:
# good---

# %% [markdown]
# ### S7P - good (some bad cases)

# %%
pd.read_csv('../epsCLump_approximateCLump/otherBNG/BioNetGen_CCP_S7P.csv', sep=',')
# Out:
#                modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    BioNetGen_CCP_S7P_0                0    87           30     30
# 1    BioNetGen_CCP_S7P_0                0    87           30     30
# 2    BioNetGen_CCP_S7P_0                0    87           30     24
# 3    BioNetGen_CCP_S7P_5                5    87           87     74
# 4    BioNetGen_CCP_S7P_5                5    87           87     76
# 5    BioNetGen_CCP_S7P_5                5    87           87     66
# 6   BioNetGen_CCP_S7P_10               10    87           86     81
# 7   BioNetGen_CCP_S7P_10               10    87           86     79
# 8   BioNetGen_CCP_S7P_10               10    87           86     66
# 9   BioNetGen_CCP_S7P_15               15    87           86     79
# 10  BioNetGen_CCP_S7P_15               15    87           86     73
# 11  BioNetGen_CCP_S7P_15               15    87           86     11
# 12  BioNetGen_CCP_S7P_20               20    87           86     79
# ...

# %%
print('bad')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_S7P_0Drift_nRows24_eps0.15469_max_alw_slope_0.3.jpg',width=700))
# Out:
# bad

# %%
print('GOOD')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_S7P_5Drift_nRows74_eps0.15547_max_alw_slope_0.1.jpg',width=700))
# Out:
# GOOD

# %%
print('bad')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_S7P_5Drift_nRows66_eps0.20032_max_alw_slope_0.3.jpg',width=700))
# Out:
# bad

# %%
print('good')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_S7P_15Drift_nRows73_eps0.16641_max_alw_slope_0.2.jpg',width=700))
# Out:
# good

# %% [markdown]
# ### All obs - it is difficult to interpret the plots

# %%
pd.read_csv('../epsCLump_approximateCLump/otherBNG/BioNetGen_CCP_AllObs.csv', sep=',')
# Out:
#                   modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    BioNetGen_CCP_AllObs_0                0    87           30     30
# 1    BioNetGen_CCP_AllObs_0                0    87           30     30
# 2    BioNetGen_CCP_AllObs_0                0    87           30     30
# 3    BioNetGen_CCP_AllObs_5                5    87           86     30
# 4    BioNetGen_CCP_AllObs_5                5    87           86     30
# 5    BioNetGen_CCP_AllObs_5                5    87           86     30
# 6   BioNetGen_CCP_AllObs_10               10    87           86     83
# 7   BioNetGen_CCP_AllObs_10               10    87           86     30
# 8   BioNetGen_CCP_AllObs_10               10    87           86     30
# 9   BioNetGen_CCP_AllObs_15               15    87           86     84
# 10  BioNetGen_CCP_AllObs_15               15    87           86     78
# 11  BioNetGen_CCP_AllObs_15               15    87           86     30
# ...

# %%
print('very good')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_AllObs_5Drift_nRows30_eps0.67912_max_alw_slope_0.1.jpg',width=700))
# Out:
# very good

# %%
print('very good')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_AllObs_10Drift_nRows30_eps0.63641_max_alw_slope_0.2.jpg',width=700))
# Out:
# very good

# %%
print('very good')
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_AllObs_15Drift_nRows30_eps0.74248_max_alw_slope_0.3.jpg',width=700))
# Out:
# very good

# %% [markdown]
# ### D13PG T_end=100

# %%
pd.read_csv('../epsCLump_approximateCLump/otherBNG/BioNetGen_CCP_D13PG100.csv', sep=',')
# Out:
#                     modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    BioNetGen_CCP_D13PG100_0                0    87           30     30
# 1    BioNetGen_CCP_D13PG100_0                0    87           30     27
# 2    BioNetGen_CCP_D13PG100_0                0    87           30     23
# 3    BioNetGen_CCP_D13PG100_0                0    87           30      9
# 4    BioNetGen_CCP_D13PG100_0                0    87           30      9
# 5    BioNetGen_CCP_D13PG100_5                5    87           86     81
# 6    BioNetGen_CCP_D13PG100_5                5    87           86     81
# 7    BioNetGen_CCP_D13PG100_5                5    87           86     66
# 8    BioNetGen_CCP_D13PG100_5                5    87           86     10
# 9    BioNetGen_CCP_D13PG100_5                5    87           86     10
# 10  BioNetGen_CCP_D13PG100_10               10    87           86     81
# 11  BioNetGen_CCP_D13PG100_10               10    87           86     78
# ...

# %%
display(Image(filename='../epsCLump_approximateCLump/otherBNG/scripts/figures/BioNetGen_CCP_D13PG100_0Drift_nRows23_eps0.34426_max_alw_slope_0.3.jpg',width=700))

# %% [markdown]
# ## NIHMS80246_S6 - GOOD

# %%
prefix='../epsCLump_approximateCLump/NIHMS80246/NIHMS80246_S6'
prefix_figures='../epsCLump_approximateCLump/NIHMS80246/scripts/figures/NIHMS80246_S6'

# %% [markdown]
# ### S1P - not interesting

# %%
view="S1P"

# %%
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                modelName  maxPerturbation  size  clump_nRows  nRows        et  \
# 0    NIHMS80246_S6_S1P_0                0    24            8      8  0.000204
# 1    NIHMS80246_S6_S1P_0                0    24            8      8  0.000204
# 2    NIHMS80246_S6_S1P_0                0    24            8      8  0.000204
# 3    NIHMS80246_S6_S1P_0                0    24            8      8  0.000204
# 4    NIHMS80246_S6_S1P_0                0    24            8      8  0.000204
# 5    NIHMS80246_S6_S1P_0                0    24            8      8  0.000204
# 6    NIHMS80246_S6_S1P_5                5    24           24     24  0.000007
# 7    NIHMS80246_S6_S1P_5                5    24           24     24  0.000007
# 8    NIHMS80246_S6_S1P_5                5    24           24     23  2.812301
# 9    NIHMS80246_S6_S1P_5                5    24           24     23  6.948420
# 10   NIHMS80246_S6_S1P_5                5    24           24     23  6.948420
# ...

# %%
print('BAD: 5% perturbation, minimal reduction, significant error')
display(Image(filename=prefix_figures+'_'+view+'_5Drift_nRows23_eps0.028125_max_alw_slope_0.3.jpg',width=700))
# Out:
# BAD: 5% perturbation, minimal reduction, significant error

# %% [markdown]
# ### S2P - good

# %%
view="S2P"

# %%
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    NIHMS80246_S6_S2P_0                0    24           19     19
# 1    NIHMS80246_S6_S2P_0                0    24           19     18
# 2    NIHMS80246_S6_S2P_0                0    24           19     15
# 3    NIHMS80246_S6_S2P_0                0    24           19     15
# 4    NIHMS80246_S6_S2P_0                0    24           19     15
# 5    NIHMS80246_S6_S2P_0                0    24           19     15
# 6    NIHMS80246_S6_S2P_5                5    24           24     24
# 7    NIHMS80246_S6_S2P_5                5    24           24     24
# 8    NIHMS80246_S6_S2P_5                5    24           24     24
# 9    NIHMS80246_S6_S2P_5                5    24           24     24
# 10   NIHMS80246_S6_S2P_5                5    24           24     24
# 11   NIHMS80246_S6_S2P_5                5    24           24     24
# 12  NIHMS80246_S6_S2P_10               10    24           24     24
# ...

# %%
print('VERY GOOD') 
display(Image(filename=prefix_figures+'_'+view+'_0Drift_nRows15_eps0.028125_max_alw_slope_0.3.jpg',width=700))
# Out:
# VERY GOOD

# %%
print('BAD: 10% PERTURBATION, MINIMAL REDUCTION, HIGH ERROR') 
display(Image(filename=prefix_figures+'_'+view+'_10Drift_nRows23_eps0.031252_max_alw_slope_0.3.jpg',width=700))
# Out:
# BAD: 10% PERTURBATION, MINIMAL REDUCTION, HIGH ERROR

# %% [markdown]
# ## NIHMS80246_S4 - GOOD

# %%
prefix='../epsCLump_approximateCLump/NIHMS80246/NIHMS80246_S4'
prefix_figures='../epsCLump_approximateCLump/NIHMS80246/scripts/figures/NIHMS80246_S4'

# %% [markdown]
# ### obsL_tot - not interesting

# %%
view="obsL_tot"
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')

# %% [markdown]
# ### obsR_tot - good

# %%
view="obsR_tot"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                     modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    NIHMS80246_S4_obsR_tot_0                0   213            4      4
# 1    NIHMS80246_S4_obsR_tot_0                0   213            4      4
# 2    NIHMS80246_S4_obsR_tot_0                0   213            4      2
# 3    NIHMS80246_S4_obsR_tot_0                0   213            4      2
# 4    NIHMS80246_S4_obsR_tot_0                0   213            4      2
# 5    NIHMS80246_S4_obsR_tot_5                5   213          213    213
# 6    NIHMS80246_S4_obsR_tot_5                5   213          213    213
# 7    NIHMS80246_S4_obsR_tot_5                5   213          213    213
# 8    NIHMS80246_S4_obsR_tot_5                5   213          213    213
# 9    NIHMS80246_S4_obsR_tot_5                5   213          213    213
# 10  NIHMS80246_S4_obsR_tot_10               10   213          213    213
# 11  NIHMS80246_S4_obsR_tot_10               10   213          213    213
# ...

# %%
print('GOOD')
display(Image(filename=prefix_figures+'_'+view+'_0Drift_nRows2_eps0.1332_max_alw_slope_0.3.jpg',width=700))
# Out:
# GOOD

# %% [markdown]
# ### obsA_tot - perfect

# %%
view="obsA_tot"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                     modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    NIHMS80246_S4_obsA_tot_0                0   213          213     33
# 1    NIHMS80246_S4_obsA_tot_0                0   213          213     33
# 2    NIHMS80246_S4_obsA_tot_0                0   213          213     33
# 3    NIHMS80246_S4_obsA_tot_0                0   213          213     33
# 4    NIHMS80246_S4_obsA_tot_0                0   213          213     33
# 5    NIHMS80246_S4_obsA_tot_5                5   213          213    213
# 6    NIHMS80246_S4_obsA_tot_5                5   213          213    213
# 7    NIHMS80246_S4_obsA_tot_5                5   213          213    213
# 8    NIHMS80246_S4_obsA_tot_5                5   213          213    213
# 9    NIHMS80246_S4_obsA_tot_5                5   213          213    213
# 10  NIHMS80246_S4_obsA_tot_10               10   213          213    213
# 11  NIHMS80246_S4_obsA_tot_10               10   213          213    213
# ...

# %%
print('PERFECT')
display(Image(filename=prefix_figures+'_'+view+'_0Drift_nRows33_eps0.010094_max_alw_slope_0.1.jpg',width=700))
# Out:
# PERFECT

# %% [markdown]
# ### obsB_tot - perfect

# %%
view="obsB_tot"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                     modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    NIHMS80246_S4_obsB_tot_0                0   213          213     33
# 1    NIHMS80246_S4_obsB_tot_0                0   213          213     33
# 2    NIHMS80246_S4_obsB_tot_0                0   213          213     33
# 3    NIHMS80246_S4_obsB_tot_0                0   213          213     33
# 4    NIHMS80246_S4_obsB_tot_0                0   213          213     33
# 5    NIHMS80246_S4_obsB_tot_5                5   213          213    213
# 6    NIHMS80246_S4_obsB_tot_5                5   213          213    213
# 7    NIHMS80246_S4_obsB_tot_5                5   213          213    213
# 8    NIHMS80246_S4_obsB_tot_5                5   213          213    213
# 9    NIHMS80246_S4_obsB_tot_5                5   213          213    213
# 10  NIHMS80246_S4_obsB_tot_10               10   213          213    213
# 11  NIHMS80246_S4_obsB_tot_10               10   213          213    213
# ...

# %%
print('PERFECT')
display(Image(filename=prefix_figures+'_'+view+'_0Drift_nRows33_eps0.011646_max_alw_slope_0.1.JPG',width=700))
# Out:
# PERFECT

# %% [markdown]
# ### obsR_dim - CRAZY RESULTS

# %%
view="obsR_dim"
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')

# %% [markdown]
# ### obsAbound - perfect

# %%
view="obsAbound"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                      modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    NIHMS80246_S4_obsAbound_0                0   213          213     33
# 1    NIHMS80246_S4_obsAbound_0                0   213          213     33
# 2    NIHMS80246_S4_obsAbound_0                0   213          213     33
# 3    NIHMS80246_S4_obsAbound_0                0   213          213     33
# 4    NIHMS80246_S4_obsAbound_0                0   213          213     33
# 5    NIHMS80246_S4_obsAbound_5                5   213          213    213
# 6    NIHMS80246_S4_obsAbound_5                5   213          213    213
# 7    NIHMS80246_S4_obsAbound_5                5   213          213    213
# 8    NIHMS80246_S4_obsAbound_5                5   213          213    213
# 9    NIHMS80246_S4_obsAbound_5                5   213          213    213
# 10  NIHMS80246_S4_obsAbound_10               10   213          213    213
# 11  NIHMS80246_S4_obsAbound_10               10   213          213    213
#
# ...

# %%
print('PERFECT')
display(Image(filename=prefix_figures+'_'+view+'_0Drift_nRows33_eps0.0091812_max_alw_slope_0.1.JPG',width=700))
# Out:
# PERFECT

# %% [markdown]
# ### obsB1pY - no clump, while we have FE. Why?

# %%
view="obsB1pY"
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')

# %% [markdown]
# ### obsB2pY - no reductions

# %%
view="obsB2pY"
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')

# %% [markdown]
# ## pcbi.1000364.s004 - 1 very good, some not sure if bad or good?

# %%
prefix='../epsCLump_approximateCLump/pcbi.1000364/pcbi_1000364_s004'
prefix_figures='../epsCLump_approximateCLump/pcbi.1000364/scripts/figures/pcbi_1000364_s004'

# %% [markdown]
# ### J_mono

# %%
view="J_mono"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                       modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    pcbi_1000364_s004_J_mono_0                0    11            3      3
# 1    pcbi_1000364_s004_J_mono_0                0    11            3      3
# 2    pcbi_1000364_s004_J_mono_0                0    11            3      3
# 3    pcbi_1000364_s004_J_mono_5                5    11           11      3
# 4    pcbi_1000364_s004_J_mono_5                5    11           11      3
# 5    pcbi_1000364_s004_J_mono_5                5    11           11      3
# 6   pcbi_1000364_s004_J_mono_10               10    11           11     11
# 7   pcbi_1000364_s004_J_mono_10               10    11           11      3
# 8   pcbi_1000364_s004_J_mono_10               10    11           11      3
# 9   pcbi_1000364_s004_J_mono_15               15    11           11     11
# 10  pcbi_1000364_s004_J_mono_15               15    11           11      3
# ...

# %%
print('bad!?')
display(Image(filename=prefix_figures+'_'+view+'_5Drift_nRows3_eps0.28757_max_alw_slope_0.1.jpg',width=700))
# Out:
# bad!?

# %%
print('bad!?')
my_display(prefix_figures,view,'_10Drift_nRows3_eps0.2_max_alw_slope_0.2.jpg')
# Out:
# bad!?

# %%
print('bad?')
my_display(prefix_figures,view,'_15Drift_nRows3_eps0.26121_max_alw_slope_0.2.jpg')
# Out:
# bad?

# %% [markdown]
# ### JS

# %%
view="JS"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                   modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    pcbi_1000364_s004_JS_0                0    11            5      5
# 1    pcbi_1000364_s004_JS_0                0    11            5      5
# 2    pcbi_1000364_s004_JS_0                0    11            5      5
# 3    pcbi_1000364_s004_JS_5                5    11           11      5
# 4    pcbi_1000364_s004_JS_5                5    11           11      5
# 5    pcbi_1000364_s004_JS_5                5    11           11      5
# 6   pcbi_1000364_s004_JS_10               10    11           11     11
# 7   pcbi_1000364_s004_JS_10               10    11           11      5
# 8   pcbi_1000364_s004_JS_10               10    11           11      5
# 9   pcbi_1000364_s004_JS_15               15    11           11     11
# 10  pcbi_1000364_s004_JS_15               15    11           11     11
# 11  pcbi_1000364_s004_JS_15               15    11           11      6
#
# ...

# %%
print('bad!?')
my_display(prefix_figures,view,'_5Drift_nRows5_eps0.29157_max_alw_slope_0.1.jpg')
# Out:
# bad!?

# %%
print('bad!?')
my_display(prefix_figures,view,'_10Drift_nRows5_eps0.34067_max_alw_slope_0.2.jpg')
# Out:
# bad!?

# %%
print('bad!?')
my_display(prefix_figures,view,'_15Drift_nRows6_eps0.31413_max_alw_slope_0.3.jpg')
# Out:
# bad!?

# %% [markdown]
# ### JSS

# %%
view="JSS"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                    modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    pcbi_1000364_s004_JSS_0                0    11            6      6
# 1    pcbi_1000364_s004_JSS_0                0    11            6      6
# 2    pcbi_1000364_s004_JSS_0                0    11            6      6
# 3    pcbi_1000364_s004_JSS_5                5    11           11      6
# 4    pcbi_1000364_s004_JSS_5                5    11           11      6
# 5    pcbi_1000364_s004_JSS_5                5    11           11      6
# 6   pcbi_1000364_s004_JSS_10               10    11           11     11
# 7   pcbi_1000364_s004_JSS_10               10    11           11     11
# 8   pcbi_1000364_s004_JSS_10               10    11           11     11
# 9   pcbi_1000364_s004_JSS_15               15    11           11     11
# 10  pcbi_1000364_s004_JSS_15               15    11           11     11
# 11  pcbi_1000364_s004_JSS_15               15    11           11     11
#
# ...

# %%
print('bad!?')
my_display(prefix_figures,view,'_5Drift_nRows6_eps0.24717_max_alw_slope_0.1.jpg')
# Out:
# bad!?

# %% [markdown]
# ### JSSJ - VERY GOOD

# %%
view="JSSJ"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                     modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0    pcbi_1000364_s004_JSSJ_0                0    11            6      6
# 1    pcbi_1000364_s004_JSSJ_0                0    11            6      5
# 2    pcbi_1000364_s004_JSSJ_0                0    11            6      5
# 3    pcbi_1000364_s004_JSSJ_5                5    11           11      6
# 4    pcbi_1000364_s004_JSSJ_5                5    11           11      5
# 5    pcbi_1000364_s004_JSSJ_5                5    11           11      5
# 6   pcbi_1000364_s004_JSSJ_10               10    11           11      6
# 7   pcbi_1000364_s004_JSSJ_10               10    11           11      5
# 8   pcbi_1000364_s004_JSSJ_10               10    11           11      5
# 9   pcbi_1000364_s004_JSSJ_15               15    11           11      6
# 10  pcbi_1000364_s004_JSSJ_15               15    11           11      5
# 11  pcbi_1000364_s004_JSSJ_15               15    11           11      5
#
# ...

# %%
my_display(prefix_figures,view,'_0Drift_nRows5_eps0.81649_max_alw_slope_0.2.jpg')

# %%
print('VERY GOOD')
my_display(prefix_figures,view,'_5Drift_nRows6_eps0.74913_max_alw_slope_0.1.jpg')
# Out:
# VERY GOOD

# %%
print('VERY GOOD ++')
my_display(prefix_figures,view,'_5Drift_nRows5_eps0.83298_max_alw_slope_0.2.jpg')
# Out:
# VERY GOOD ++

# %%
print('GOOD?')
my_display(prefix_figures,view,'_10Drift_nRows6_eps0.2_max_alw_slope_0.1.jpg')
# Out:
# GOOD?

# %%
print('GOOD-?')
my_display(prefix_figures,view,'_10Drift_nRows5_eps0.84674_max_alw_slope_0.2.jpg')
# Out:
# GOOD-?

# %%
print('GOOD-?')
my_display(prefix_figures,view,'_15Drift_nRows6_eps0.30117_max_alw_slope_0.1.jpg')
# Out:
# GOOD-?

# %%
print('VERY GOOD!')
my_display(prefix_figures,view,'_15Drift_nRows5_eps0.79095_max_alw_slope_0.2.jpg')
# Out:
# VERY GOOD!

# %% [markdown]
# ### J_active-not interesting

# %%
view="J_active"
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')

# %% [markdown]
# ### J_inactive-not interesting

# %%
view="J_inactive"
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')

# %%
#view="Macrocomplex"
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')

# %% [markdown]
# ## journal.pcbi.1003544.s006 - GOOD!

# %%
prefix='../epsCLump_approximateCLump/otherBNG2/journal_pcbi_1003544_s006'
prefix_figures='../epsCLump_approximateCLump/otherBNG2/scripts/figures/journal_pcbi_1003544_s006'

# %% [markdown]
# ### LR - not interesting

# %%
view="LR"
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')

# %% [markdown]
# ### Rp - some results

# %%
view="Rp"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                           modelName  maxPerturbation  size  clump_nRows  \
# 0    journal_pcbi_1003544_s006_Rp_0                0    62           62
# 1    journal_pcbi_1003544_s006_Rp_0                0    62           62
# 2    journal_pcbi_1003544_s006_Rp_0                0    62           62
# 3    journal_pcbi_1003544_s006_Rp_0                0    62           62
# 4    journal_pcbi_1003544_s006_Rp_5                5    62           62
# 5    journal_pcbi_1003544_s006_Rp_5                5    62           62
# 6    journal_pcbi_1003544_s006_Rp_5                5    62           62
# 7    journal_pcbi_1003544_s006_Rp_5                5    62           62
# 8   journal_pcbi_1003544_s006_Rp_10               10    62           62
# 9   journal_pcbi_1003544_s006_Rp_10               10    62           62
# 10  journal_pcbi_1003544_s006_Rp_10               10    62           62
#
#     nRows            et        et_rel  |M*xt|_2   epsilon  max_allowed_slope  \
# ...

# %%
my_display(prefix_figures,view,'_0Drift_nRows34_eps0.00078125_max_alw_slope_0.2.jpg')

# %%
my_display(prefix_figures,view,'_0Drift_nRows33_eps0.00084229_max_alw_slope_0.4.jpg')

# %% [markdown]
# ### Ap - very good!

# %%
view="Ap"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                          modelName  maxPerturbation  size  clump_nRows  nRows  \
# 0   journal_pcbi_1003544_s006_Ap_0                0    62           62     28
# 1   journal_pcbi_1003544_s006_Ap_0                0    62           62     28
# 2   journal_pcbi_1003544_s006_Ap_0                0    62           62     28
# 3   journal_pcbi_1003544_s006_Ap_0                0    62           62     28
# 4   journal_pcbi_1003544_s006_Ap_5                5    62           62     62
# 5   journal_pcbi_1003544_s006_Ap_5                5    62           62     62
# 6   journal_pcbi_1003544_s006_Ap_5                5    62           62     62
# 7   journal_pcbi_1003544_s006_Ap_5                5    62           62     62
# 8  journal_pcbi_1003544_s006_Ap_10               10    62           62     62
#
#              et        et_rel  |M*xt|_2   epsilon  max_allowed_slope  \
# 0  2.252705e-10  1.232232e-10  182.8150  0.000995                0.2
# ...

# %%
print('very good!')
my_display(prefix_figures,view,'_0Drift_nRows28_eps0.00099487_max_alw_slope_0.2.jpg')
# Out:
# very good!

# %% [markdown]
# ### RC - not interesting

# %%
view="RC"
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')

# %%
#my_display(prefix_figures,view,'_0Drift')

# %% [markdown]
# ### Ltot - too much clump reduction

# %%
view="Ltot"
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')

# %% [markdown]
# ### Rtot - too much clump reduction

# %%
view="Rtot"
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')

# %% [markdown]
# ### Atot-too much clump

# %%
view="Atot"
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')

# %% [markdown]
# ### Btot - bad

# %%
view="Btot"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                             modelName  maxPerturbation  size  clump_nRows  \
# 0    journal_pcbi_1003544_s006_Btot_0                0    62           62
# 1    journal_pcbi_1003544_s006_Btot_0                0    62           62
# 2    journal_pcbi_1003544_s006_Btot_0                0    62           62
# 3    journal_pcbi_1003544_s006_Btot_0                0    62           62
# 4    journal_pcbi_1003544_s006_Btot_5                5    62           62
# 5    journal_pcbi_1003544_s006_Btot_5                5    62           62
# 6    journal_pcbi_1003544_s006_Btot_5                5    62           62
# 7    journal_pcbi_1003544_s006_Btot_5                5    62           62
# 8   journal_pcbi_1003544_s006_Btot_10               10    62           62
# 9   journal_pcbi_1003544_s006_Btot_10               10    62           62
# 10  journal_pcbi_1003544_s006_Btot_10               10    62           62
# 11  journal_pcbi_1003544_s006_Btot_10               10    62           62
# ...

# %%
my_display(prefix_figures,view,'_0Drift_nRows44_eps0.00099335_max_alw_slope_0.2.jpg')

# %% [markdown]
# ### Ctot - super BAD

# %%
view="Ctot"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                             modelName  maxPerturbation  size  clump_nRows  \
# 0    journal_pcbi_1003544_s006_Ctot_0                0    62           62
# 1    journal_pcbi_1003544_s006_Ctot_0                0    62           62
# 2    journal_pcbi_1003544_s006_Ctot_0                0    62           62
# 3    journal_pcbi_1003544_s006_Ctot_0                0    62           62
# 4    journal_pcbi_1003544_s006_Ctot_5                5    62           62
# 5    journal_pcbi_1003544_s006_Ctot_5                5    62           62
# 6    journal_pcbi_1003544_s006_Ctot_5                5    62           62
# 7    journal_pcbi_1003544_s006_Ctot_5                5    62           62
# 8   journal_pcbi_1003544_s006_Ctot_10               10    62           62
# 9   journal_pcbi_1003544_s006_Ctot_10               10    62           62
# 10  journal_pcbi_1003544_s006_Ctot_10               10    62           62
# 11  journal_pcbi_1003544_s006_Ctot_10               10    62           62
# ...

# %%
my_display(prefix_figures,view,'_0Drift_nRows59_eps0.00091095_max_alw_slope_0.2.jpg')

# %% [markdown]
# ## journal.pcbi.1004611.s003 - perfect but low reductions

# %%
prefix='../epsCLump_approximateCLump/otherBNG2/journal_pcbi_1004611_s003'
prefix_figures='../epsCLump_approximateCLump/otherBNG2/scripts/figures/journal_pcbi_1004611_s003'

# %% [markdown]
# ### Phos_TF-perfect but low reduction

# %%
view="Phos_TF"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                                modelName  maxPerturbation  size  clump_nRows  \
# 0    journal_pcbi_1004611_s003_Phos_TF_0                0    78           78
# 1    journal_pcbi_1004611_s003_Phos_TF_0                0    78           78
# 2    journal_pcbi_1004611_s003_Phos_TF_0                0    78           78
# 3    journal_pcbi_1004611_s003_Phos_TF_5                5    78           78
# 4    journal_pcbi_1004611_s003_Phos_TF_5                5    78           78
# 5    journal_pcbi_1004611_s003_Phos_TF_5                5    78           78
# 6   journal_pcbi_1004611_s003_Phos_TF_10               10    78           78
# 7   journal_pcbi_1004611_s003_Phos_TF_10               10    78           78
# 8   journal_pcbi_1004611_s003_Phos_TF_10               10    78           78
# 9   journal_pcbi_1004611_s003_Phos_TF_15               15    78           78
# 10  journal_pcbi_1004611_s003_Phos_TF_15               15    78           78
# ...

# %%
print('perfect')
my_display(prefix_figures,view,'_0Drift_nRows73_eps0.01129_max_alw_slope_0.1.jpg')
# Out:
# perfect

# %% [markdown]
# ### Bound_prom1-perfect but low reduction

# %%
view="Bound_prom1"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                                    modelName  maxPerturbation  size  \
# 0    journal_pcbi_1004611_s003_Bound_prom1_0                0    78
# 1    journal_pcbi_1004611_s003_Bound_prom1_0                0    78
# 2    journal_pcbi_1004611_s003_Bound_prom1_0                0    78
# 3    journal_pcbi_1004611_s003_Bound_prom1_5                5    78
# 4    journal_pcbi_1004611_s003_Bound_prom1_5                5    78
# 5    journal_pcbi_1004611_s003_Bound_prom1_5                5    78
# 6   journal_pcbi_1004611_s003_Bound_prom1_10               10    78
# 7   journal_pcbi_1004611_s003_Bound_prom1_10               10    78
# 8   journal_pcbi_1004611_s003_Bound_prom1_10               10    78
# 9   journal_pcbi_1004611_s003_Bound_prom1_15               15    78
# 10  journal_pcbi_1004611_s003_Bound_prom1_15               15    78
# 11  journal_pcbi_1004611_s003_Bound_prom1_15               15    78
#
#     clump_nRows  nRows            et    et_rel  |M*xt|_2   epsilon  \
# ...

# %%
print('perfect')
my_display(prefix_figures,view,'_5Drift_nRows74_eps0.017868_max_alw_slope_0.1.jpg')
# Out:
# perfect

# %% [markdown]
# ### P1_NU-perfect but low reductions

# %%
view="P1_NU"
pd.read_csv(prefix+'_'+view+'.csv', sep=',')
# Out:
#                              modelName  maxPerturbation  size  clump_nRows  \
# 0    journal_pcbi_1004611_s003_P1_NU_0                0    78           78
# 1    journal_pcbi_1004611_s003_P1_NU_0                0    78           78
# 2    journal_pcbi_1004611_s003_P1_NU_0                0    78           78
# 3    journal_pcbi_1004611_s003_P1_NU_5                5    78           74
# 4    journal_pcbi_1004611_s003_P1_NU_5                5    78           74
# 5    journal_pcbi_1004611_s003_P1_NU_5                5    78           74
# 6   journal_pcbi_1004611_s003_P1_NU_10               10    78           74
# 7   journal_pcbi_1004611_s003_P1_NU_10               10    78           74
# 8   journal_pcbi_1004611_s003_P1_NU_10               10    78           74
# 9   journal_pcbi_1004611_s003_P1_NU_15               15    78           74
# 10  journal_pcbi_1004611_s003_P1_NU_15               15    78           74
# ...

# %%
my_display(prefix_figures,view,'_0Drift_nRows73_eps0.017676_max_alw_slope_0.1.jpg')

# %% [markdown]
# ## HTree depth 3 - NOT INTERESTING

# %%
prefix='../epsCLump_approximateCLump/htree/hTreeCircuit3_1RN'
prefix_figures='../epsCLump_approximateCLump/htree/scripts/figures/hTreeCircuit3_1RN'

# %%
view=""
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')
pd.read_csv(prefix+'.csv', sep=',')
# Out:
#              modelName  maxPerturbation  size  clump_nRows  nRows        et  \
# 0  hTreeCircuit3_1RN_0                0     7            2      1  0.012865
#
#      et_rel  |M*xt|_2  epsilon  max_allowed_slope  avg_err   max_err  \
# 0  99.99999  0.012865     49.9                  1  0.56183  0.996728
#
#    max_allowed_err  compactum_bound  norm_fx0  consideredEpsilons  tolerance  \
# 0         2.348127                1  2.348127                 500   0.000001
#
#    secThisEpsilon  secTotal
# 0          0.0233   12.6352

# %%
prefix='../epsCLump_approximateCLump/htree/hTreeCircuit3_1RN_2'
prefix_figures='../epsCLump_approximateCLump/htree/scripts/figures/hTreeCircuit3_1RN_2'

# %%
view=""
#pd.read_csv(prefix+'_'+view+'.csv', sep=',')
pd.read_csv(prefix+'.csv', sep=',')
# Out:
#                modelName  maxPerturbation  size  clump_nRows  nRows        et  \
# 0  hTreeCircuit3_1RN_2_0                0     7            3      1  0.013104
#
#      et_rel  |M*xt|_2  epsilon  max_allowed_slope   avg_err   max_err  \
# 0  99.99999  0.013104     49.9                  1  0.570585  1.044866
#
#    max_allowed_err  compactum_bound  norm_fx0  consideredEpsilons  tolerance  \
# 0         2.343779                1  2.343779                 500   0.000001
#
#    secThisEpsilon  secTotal
# 0          0.0214   11.9929
